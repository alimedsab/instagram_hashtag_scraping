# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
import time

# %%
driver=webdriver.Firefox()
driver.get("https://www.instagram.com")
time.sleep(10)

# %%
def login(username,password):
    username1=driver.find_element_by_xpath("//input[@name='username']")
    password1=driver.find_element_by_xpath("//input[@name='password']")

    username1.clear()
    password1.clear()
    username1.send_keys(username)
    password1.send_keys(password)
    log_in=driver.find_element_by_xpath("//button[@type='submit']").click()

# %%
login("username","password")
time.sleep(4)
def skip_not_now():
    not_now=driver.find_element_by_xpath("//button[contains(text(),'Not now')]").click()
    time.sleep(1)
    not_now2=driver.find_element_by_xpath("//button[contains(text(),'Not Now')]").click()
# Out:
# /tmp/ipykernel_37879/3208122259.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username1=driver.find_element_by_xpath("//input[@name='username']")
# /tmp/ipykernel_37879/3208122259.py:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   password1=driver.find_element_by_xpath("//input[@name='password']")
# /tmp/ipykernel_37879/3208122259.py:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   log_in=driver.find_element_by_xpath("//button[@type='submit']").click()
# /tmp/ipykernel_37879/3423827615.py:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   not_now2=driver.find_element_by_xpath("//button[contains(text(),'Not Now')]").click()

# %%
def search_for_hashtag(hashtag):
    searchbox=driver.find_element_by_xpath("//input[@placeholder='Search']")
    searchbox.clear()
    keyword=hashtag
    searchbox.send_keys(keyword)
    find_hashtag_tab=driver.find_element_by_xpath("//a[@class='-qQT3']").click()

# %%
search_for_hashtag("#gym")
# Out:
# /tmp/ipykernel_37879/2230803539.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   searchbox=driver.find_element_by_xpath("//input[@placeholder='Search']")
# /tmp/ipykernel_37879/2230803539.py:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   find_hashtag_tab=driver.find_element_by_xpath("//a[@class='-qQT3']").click()

# %%
def hashtag_graber(number_of_posts):
    open_post=driver.find_element_by_class_name("eLAPa").click()
    i=number_of_posts
    lanvr=True
    while lanvr:
        try:
            name=driver.find_element_by_class_name("ZIAjV").text
            number_of_likes=driver.find_element_by_class_name("zV_Nj").text
            link=driver.current_url
            hashtags=driver.find_elements_by_class_name("xil3i")
            for hashtag in hashtags:
                print(hashtag.text)
        except:
            pass
        driver.find_element_by_xpath("//*[@aria-label='Next']").click()
        i=i-1
        if i==0:
            print("fin")
            lanvr=False
            time.sleep(2)
        else:
            pass

# %%
hashtag_graber(10)
# Out:
# /tmp/ipykernel_37879/1232655063.py:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   open_post=driver.find_element_by_class_name("eLAPa").click()
# /tmp/ipykernel_37879/1232655063.py:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name=driver.find_element_by_class_name("ZIAjV").text
# /tmp/ipykernel_37879/1232655063.py:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   number_of_likes=driver.find_element_by_class_name("zV_Nj").text
# /tmp/ipykernel_37879/1232655063.py:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   hashtags=driver.find_elements_by_class_name("xil3i")
# #тренерхарьков
# #тренеронлайн
# #фитнестренер
# #персональныйтренер
# #тренажерныйзал
# #фитнесмотивация
# #мотивациякаждыйдень
# #бодибилдинг
# #тренер
# #бицепс
# #gym
# #motivation
# #muscle
# ...
